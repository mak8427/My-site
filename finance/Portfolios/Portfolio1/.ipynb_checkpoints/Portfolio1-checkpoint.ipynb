# %% [raw]
# Portfolio1Portfolio1

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import random
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('error', category=DeprecationWarning)

# %%
giorni_anno=253
df=yf.download("IWDA.AS")["Adj Close"].pct_change(giorni_anno).dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
primo_estratto=random.randint(0,len(df)-3*giorni_anno-1)
secondo_estratto=primo_estratto+giorni_anno
terzo_estratto=secondo_estratto+giorni_anno
print(df.index[primo_estratto],"->",round(df[primo_estratto]*100),"%")
print(df.index[secondo_estratto],"->",round(df[secondo_estratto]*100),"%")
print(df.index[terzo_estratto],"->",round(df[terzo_estratto]*100),"%")
# Out:
# 2013-06-21 00:00:00 -> 16 %
# 2014-06-19 00:00:00 -> 22 %
# 2015-06-17 00:00:00 -> 25 %
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4214205551.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.index[primo_estratto],"->",round(df[primo_estratto]*100),"%")
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4214205551.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.index[secondo_estratto],"->",round(df[secondo_estratto]*100),"%")
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4214205551.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.index[terzo_estratto],"->",round(df[terzo_estratto]*100),"%")

# %%
quante_simulazioni=100
upper=len(df)-3*giorni_anno-1
m=np.zeros((100,quante_simulazioni))
m[0,:]=1
for c in range(quante_simulazioni):
    for t in range(1,100,3):
        e1=random.randint(0,upper)
        e2=e1+giorni_anno
        e3=e2+giorni_anno
        # print(t,c)
        m[t,c]=m[t-1,c]*(1+df[e1])
        m[t+1,c]=m[t,c]*(1+df[e2])
        m[t+2,c]=m[t+1,c]*(1+df[e3])
# Out:
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4008517749.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   m[t,c]=m[t-1,c]*(1+df[e1])
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4008517749.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   m[t+1,c]=m[t,c]*(1+df[e2])
# C:\Users\dadoi\AppData\Local\Temp\ipykernel_13000\4008517749.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   m[t+2,c]=m[t+1,c]*(1+df[e3])

# %%
m
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [1.20544136e+00, 1.01485772e+00, 1.09175864e+00, ...,
#         1.23524701e+00, 1.21716966e+00, 1.18253736e+00],
#        [1.18573011e+00, 1.09277533e+00, 1.17941090e+00, ...,
#         1.53010593e+00, 1.26719029e+00, 1.21820900e+00],
#        ...,
#        [2.74471544e+04, 1.56339390e+05, 1.27557556e+05, ...,
#         3.99111620e+04, 5.09545914e+04, 7.51420998e+04],
#        [3.62215033e+04, 1.75134288e+05, 1.23638086e+05, ...,
#         4.38255567e+04, 5.55416507e+04, 9.83817863e+04],
#        [3.40188152e+04, 2.38200931e+05, 1.43151997e+05, ...,
#         4.48814939e+04, 7.43199255e+04, 1.05123586e+05]])

# %%
pd.DataFrame(m).plot(legend=None,logy=True,fontsize=16,figsize=(25,15))

# %%
# !jupyter nbconvert --to html Portfolio1.ipynb
